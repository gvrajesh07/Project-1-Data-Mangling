# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv')
df.head(2)
# Out:
#                           Indicator PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv')
df1.head(2)
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
#
#    TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
#
# [2 rows x 21 columns]

# %%
#1. Get the Metadata from the above files.
df.info()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
# Indicator                  4656 non-null object
# PUBLISH STATES             4656 non-null object
# Year                       4656 non-null int64
# WHO region                 4656 non-null object
# World Bank income group    4656 non-null object
# Country                    4656 non-null object
# Sex                        4656 non-null object
# Display Value              4656 non-null int64
# Numeric                    4656 non-null float64
# Low                        0 non-null float64
# High                       0 non-null float64
# Comments                   0 non-null float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
# STATION         117208 non-null object
# STATION_NAME    117208 non-null object
# ...

# %%
#2. Get the row names from the above file.

print(df.axes[0])
print(df1.axes[0])
# Out:
# RangeIndex(start=0, stop=4656, step=1)
# RangeIndex(start=0, stop=117208, step=1)

# %%
#3. Change the column name from any of the above file.
print(df.rename({'Indicator':'Indicator_Id'},axis=1).head(2))
print('='*90)
print(df1.rename({'STATION':'STATION_ID'},axis=1).head(2))
# Out:
#                        Indicator_Id PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN
# ...
#           STATION_ID         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
#
#    TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
# ...

# %%
#4. Change the column name from any of the above file and store the changes made permanently.
df=df.rename({'Indicator':'Indicator_Id'},axis=1)
df1=df1.rename({'STATION':'STATION_ID'},axis=1)
print(df.head(2))
print('='*90)
print(df1.head(2))
# Out:
#                        Indicator_Id PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN
# ...
#           STATION_ID         STATION NAME      YEAR  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
#
#    TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
# ...

# %%
#5. Change the names of multiple columns.
df=df.rename({'PUBLISH STATES':'Publication Status','WHO region':'WHO Region'},axis=1)
df1=df1.rename({'STATION_NAME':'STATION NAME','DATE':'YEAR'},axis=1)
print(df.head(2))
print('='*90)
print(df1.head(2))
# Out:
#                           Indicator Publication Status  Year WHO Region  \
# 0  Life expectancy at birth (years)          Published  1990     Europe
# 1  Life expectancy at birth (years)          Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN
# ...
#              STATION         STATION NAME      YEAR  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
#
#    TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
# ...

# %%
#6. Arrange values of a particular column in ascending order.
df.sort_values('Year',ascending=True)
# Out:
#                                             Indicator Publication Status  \
# 0                    Life expectancy at birth (years)          Published
# 1270                 Life expectancy at birth (years)          Published
# 3193                 Life expectancy at birth (years)          Published
# 3194                 Life expectancy at birth (years)          Published
# 3197                Life expectancy at age 60 (years)          Published
# 1264                 Life expectancy at birth (years)          Published
# 3199                Life expectancy at age 60 (years)          Published
# 1262                Life expectancy at age 60 (years)          Published
# 1259                 Life expectancy at birth (years)          Published
# 3203                Life expectancy at age 60 (years)          Published
# 1273                Life expectancy at age 60 (years)          Published
# 3204                 Life expectancy at birth (years)          Published
# ...

# %%
df1.sort_values('YEAR',ascending=True)
# Out:
#                   STATION         STATION NAME      YEAR  PRCP  SNWD  SNOW  \
# 22874   GHCND:GM000003319     BERLIN DAHLEM GM  19000101     6 -9999 -9999
# 59209   GHCND:GM000003342           POTSDAM GM  19000101     4    60 -9999
# 22875   GHCND:GM000003319     BERLIN DAHLEM GM  19000102     2 -9999 -9999
# 59210   GHCND:GM000003342           POTSDAM GM  19000102    45    50 -9999
# 59211   GHCND:GM000003342           POTSDAM GM  19000103    26    20 -9999
# 22876   GHCND:GM000003319     BERLIN DAHLEM GM  19000103    43 -9999 -9999
# 22877   GHCND:GM000003319     BERLIN DAHLEM GM  19000104    15 -9999 -9999
# 59212   GHCND:GM000003342           POTSDAM GM  19000104     0     0 -9999
# 22878   GHCND:GM000003319     BERLIN DAHLEM GM  19000105     0 -9999 -9999
# 59213   GHCND:GM000003342           POTSDAM GM  19000105     2     0 -9999
# 22879   GHCND:GM000003319     BERLIN DAHLEM GM  19000106     1 -9999 -9999
# ...

# %%
df.sort_values(['WHO Region','Year'],ascending=True)
# Out:
#                                             Indicator Publication Status  \
# 64                  Life expectancy at age 60 (years)          Published
# 149                  Life expectancy at birth (years)          Published
# 151                  Life expectancy at birth (years)          Published
# 155                  Life expectancy at birth (years)          Published
# 158                 Life expectancy at age 60 (years)          Published
# 165                  Life expectancy at birth (years)          Published
# 167                  Life expectancy at birth (years)          Published
# 168                 Life expectancy at age 60 (years)          Published
# 172                 Life expectancy at age 60 (years)          Published
# 177                 Life expectancy at age 60 (years)          Published
# 181                  Life expectancy at birth (years)          Published
# 186                 Life expectancy at age 60 (years)          Published
# ...

# %%
#7. Arrange multiple column values in ascending order.
df1.sort_values(['STATION NAME','YEAR'],ascending=True)
# Out:
#                   STATION      STATION NAME      YEAR  PRCP  SNWD  SNOW  TMAX  \
# 22874   GHCND:GM000003319  BERLIN DAHLEM GM  19000101     6 -9999 -9999    28
# 22875   GHCND:GM000003319  BERLIN DAHLEM GM  19000102     2 -9999 -9999    29
# 22876   GHCND:GM000003319  BERLIN DAHLEM GM  19000103    43 -9999 -9999    69
# 22877   GHCND:GM000003319  BERLIN DAHLEM GM  19000104    15 -9999 -9999    75
# 22878   GHCND:GM000003319  BERLIN DAHLEM GM  19000105     0 -9999 -9999    50
# 22879   GHCND:GM000003319  BERLIN DAHLEM GM  19000106     1 -9999 -9999    11
# 22880   GHCND:GM000003319  BERLIN DAHLEM GM  19000107     0 -9999 -9999     6
# 22881   GHCND:GM000003319  BERLIN DAHLEM GM  19000108     0 -9999 -9999     4
# 22882   GHCND:GM000003319  BERLIN DAHLEM GM  19000109     0 -9999 -9999    28
# 22883   GHCND:GM000003319  BERLIN DAHLEM GM  19000110    14 -9999 -9999    28
# 22884   GHCND:GM000003319  BERLIN DAHLEM GM  19000111     0 -9999 -9999    14
# ...

# %%
#8. Make country as the first column of the dataframe.
df=df[['Country','Indicator', 'Publication Status', 'Year', 'WHO Region','World Bank income group', 'Sex', 'Display Value', 'Numeric','Low', 'High', 'Comments']]
df.head(2)
# Out:
#    Country                         Indicator Publication Status  Year  \
# 0  Andorra  Life expectancy at birth (years)          Published  1990
# 1  Andorra  Life expectancy at birth (years)          Published  2000
#
#   WHO Region World Bank income group         Sex  Display Value  Numeric  Low  \
# 0     Europe             High-income  Both sexes             77     77.0  NaN
# 1     Europe             High-income  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
#9. Get the column array using a variable
df['WHO Region'].values
# Out:
# array(['Europe', 'Europe', 'Europe', ..., 'Africa', 'Africa', 'Africa'], dtype=object)

# %%
#10. Get the subset rows 11, 24, 37
df.iloc[[11,24,37]]
# Out:
#               Country                          Indicator Publication Status  \
# 11            Austria   Life expectancy at birth (years)          Published
# 24  Brunei Darussalam  Life expectancy at age 60 (years)          Published
# 37             Cyprus  Life expectancy at age 60 (years)          Published
#
#     Year       WHO Region World Bank income group     Sex  Display Value  \
# 11  2012           Europe             High-income  Female             83
# 24  2012  Western Pacific             High-income  Female             21
# 37  2012           Europe             High-income  Female             26
#
#     Numeric  Low  High  Comments
# 11     83.0  NaN   NaN       NaN
# 24     21.0  NaN   NaN       NaN
# 37     26.0  NaN   NaN       NaN

# %%
#11. Get the subset rows excluding 5, 12, 23, and 56
df.drop([5,12,23,56])
# Out:
#                                  Country  \
# 0                                Andorra
# 1                                Andorra
# 2                                Andorra
# 3                                Andorra
# 4                   United Arab Emirates
# 6                    Antigua and Barbuda
# 7                    Antigua and Barbuda
# 8                              Australia
# 9                              Australia
# 10                             Australia
# 11                               Austria
# 13                               Belgium
# 14                               Bahrain
# 15                               Bahrain
# 16                               Bahrain
# 17                               Bahamas
# 18                               Bahamas
# 19                              Barbados
# 20                              Barbados
# 21                              Barbados
# 22                     Brunei Darussalam
# 24                     Brunei Darussalam
# ...

# %%
users = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv' )
sessions = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv' )
products = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv' )
transactions = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv')
print(users.head(2))
print('='*80)
print(sessions.head(2))
print('='*80)
print(products.head(2))
print('='*80)
print(transactions.head(2))
# Out:
#    UserID     User Gender  Registered   Cancelled
# 0       1  Charles   male  2012-12-21         NaN
# 1       2    Pedro   male  2010-08-01  2010-08-08
# ...
#    SessionID SessionDate  UserID
# 0          1  2010-01-05       2
# 1          2  2010-08-01       2
# ...
#    ProductID Product  Price
# 0          1       A  14.16
# 1          2       B  33.04
# ...
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1

# %%
#12. Join users to transactions, keeping all rows from transactions and only matching rows from users (left join)
pd.merge(users,transactions,on='UserID',how='left')
# Out:
#    UserID      User  Gender  Registered   Cancelled  TransactionID  \
# 0       1   Charles    male  2012-12-21         NaN            4.0
# 1       2     Pedro    male  2010-08-01  2010-08-08            5.0
# 2       2     Pedro    male  2010-08-01  2010-08-08            6.0
# 3       3  Caroline  female  2012-10-23  2016-06-07            2.0
# 4       3  Caroline  female  2012-10-23  2016-06-07            3.0
# 5       3  Caroline  female  2012-10-23  2016-06-07            7.0
# 6       3  Caroline  female  2012-10-23  2016-06-07           10.0
# 7       4   Brielle  female  2013-07-17         NaN            NaN
# 8       5  Benjamin    male  2010-11-25         NaN            NaN
#
#   TransactionDate  ProductID  Quantity
# 0      2012-08-26        2.0       3.0
# 1      2013-06-06        4.0       1.0
# 2      2013-12-23        5.0       6.0
# 3      2011-05-26        4.0       1.0
# 4      2011-06-16        3.0       1.0
# 5      2013-12-30        4.0       1.0
# ...

# %%
#13. Which transactions have a UserID not in users?
userids=pd.merge(transactions,users,on='UserID',how='left' )
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              1      2010-08-21     7.0          2         1       NaN
# 1              2      2011-05-26     3.0          4         1  Caroline
# 2              3      2011-06-16     3.0          3         1  Caroline
# 3              4      2012-08-26     1.0          2         3   Charles
# 4              5      2013-06-06     2.0          4         1     Pedro
#
#    Gender  Registered   Cancelled
# 0     NaN         NaN         NaN
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3    male  2012-12-21         NaN
# 4    male  2010-08-01  2010-08-08

# %%
#14. Join users to transactions, keeping only rows from transactions and users that match via UserID (inner join)
pd.merge(users,transactions,on='UserID',how='inner')
# Out:
#    UserID      User  Gender  Registered   Cancelled  TransactionID  \
# 0       1   Charles    male  2012-12-21         NaN              4
# 1       2     Pedro    male  2010-08-01  2010-08-08              5
# 2       2     Pedro    male  2010-08-01  2010-08-08              6
# 3       3  Caroline  female  2012-10-23  2016-06-07              2
# 4       3  Caroline  female  2012-10-23  2016-06-07              3
# 5       3  Caroline  female  2012-10-23  2016-06-07              7
# 6       3  Caroline  female  2012-10-23  2016-06-07             10
#
#   TransactionDate  ProductID  Quantity
# 0      2012-08-26          2         3
# 1      2013-06-06          4         1
# 2      2013-12-23          5         6
# 3      2011-05-26          4         1
# 4      2011-06-16          3         1
# 5      2013-12-30          4         1
# 6      2016-05-08          4         4

# %%
#15. Join users to transactions, displaying all matching rows AND all non-matching rows (full outer join)
pd.merge(users,sessions,on='UserID',how='outer')
# Out:
#     UserID      User  Gender  Registered   Cancelled  SessionID SessionDate
# 0        1   Charles    male  2012-12-21         NaN        NaN         NaN
# 1        2     Pedro    male  2010-08-01  2010-08-08        1.0  2010-01-05
# 2        2     Pedro    male  2010-08-01  2010-08-08        2.0  2010-08-01
# 3        2     Pedro    male  2010-08-01  2010-08-08        3.0  2010-11-25
# 4        3  Caroline  female  2012-10-23  2016-06-07        7.0  2012-12-21
# 5        4   Brielle  female  2013-07-17         NaN        5.0  2011-10-19
# 6        4   Brielle  female  2013-07-17         NaN        6.0  2012-10-23
# 7        4   Brielle  female  2013-07-17         NaN        8.0  2013-05-22
# 8        4   Brielle  female  2013-07-17         NaN        9.0  2013-07-17
# 9        4   Brielle  female  2013-07-17         NaN       10.0  2016-01-11
# 10       5  Benjamin    male  2010-11-25         NaN        4.0  2011-09-21

# %%
#16. Determine which sessions occurred on the same day each user registered
pd.merge(users,sessions, left_on='Registered',right_on='SessionDate')
# Out:
#    UserID_x      User  Gender  Registered   Cancelled  SessionID SessionDate  \
# 0         1   Charles    male  2012-12-21         NaN          7  2012-12-21
# 1         2     Pedro    male  2010-08-01  2010-08-08          2  2010-08-01
# 2         3  Caroline  female  2012-10-23  2016-06-07          6  2012-10-23
# 3         4   Brielle  female  2013-07-17         NaN          9  2013-07-17
# 4         5  Benjamin    male  2010-11-25         NaN          3  2010-11-25
#
#    UserID_y
# 0         3
# 1         2
# 2         4
# 3         4
# 4         2

# %%
#17. Build a dataset with every possible (UserID, ProductID) pair (cross join)
users['tmp']=1
products['tmp']=1
pd.merge(users,products,on='tmp').loc[:,('UserID','ProductID')]
# Out:
#     UserID  ProductID
# 0        1          1
# 1        1          2
# 2        1          3
# 3        1          4
# 4        1          5
# 5        2          1
# 6        2          2
# 7        2          3
# 8        2          4
# 9        2          5
# 10       3          1
# 11       3          2
# 12       3          3
# 13       3          4
# 14       3          5
# 15       4          1
# 16       4          2
# 17       4          3
# 18       4          4
# 19       4          5
# 20       5          1
# 21       5          2
# 22       5          3
# 23       5          4
# 24       5          5

# %%
#users.drop('tmp',axis=1,inplace=True)
pd.merge(users,products,on='tmp').loc[:,('UserID','ProductID')]

# %%
#18. Determine how much quantity of each product was purchased by each user
#products_df=pd.DataFrame(products)
products.drop('tmp',axis=1,inplace=True)

# %%
transactions.groupby(['UserID','ProductID'])['Quantity'].sum()
# Out:
# UserID  ProductID
# 1.0     2            3
# 2.0     4            1
#         5            6
# 3.0     3            1
#         4            6
# 7.0     2            1
#         4            3
# Name: Quantity, dtype: int64

# %%
#19. For each user, get each possible pair of pair transactions (TransactionID1, TransacationID2)
transactions.merge(transactions,left_on='UserID',right_on='UserID')
# Out:
#     TransactionID_x TransactionDate_x  UserID  ProductID_x  Quantity_x  \
# 0                 1        2010-08-21     7.0            2           1
# 1                 1        2010-08-21     7.0            2           1
# 2                 9        2015-04-24     7.0            4           3
# 3                 9        2015-04-24     7.0            4           3
# 4                 2        2011-05-26     3.0            4           1
# 5                 2        2011-05-26     3.0            4           1
# 6                 2        2011-05-26     3.0            4           1
# 7                 2        2011-05-26     3.0            4           1
# 8                 3        2011-06-16     3.0            3           1
# 9                 3        2011-06-16     3.0            3           1
# 10                3        2011-06-16     3.0            3           1
# 11                3        2011-06-16     3.0            3           1
# ...

# %%
#20. Join each user to his/her first occuring transaction in the transactions table
users.merge(transactions,how='inner',on='UserID').sort_values(by='TransactionDate')
# Out:
#    UserID      User  Gender  Registered   Cancelled  tmp  TransactionID  \
# 3       3  Caroline  female  2012-10-23  2016-06-07    1              2
# 4       3  Caroline  female  2012-10-23  2016-06-07    1              3
# 0       1   Charles    male  2012-12-21         NaN    1              4
# 1       2     Pedro    male  2010-08-01  2010-08-08    1              5
# 2       2     Pedro    male  2010-08-01  2010-08-08    1              6
# 5       3  Caroline  female  2012-10-23  2016-06-07    1              7
# 6       3  Caroline  female  2012-10-23  2016-06-07    1             10
#
#   TransactionDate  ProductID  Quantity
# 3      2011-05-26          4         1
# 4      2011-06-16          3         1
# 0      2012-08-26          2         3
# 1      2013-06-06          4         1
# 2      2013-12-23          5         6
# 5      2013-12-30          4         1
# 6      2016-05-08          4         4

# %%
#21. Test to see if we can drop columns
my_columns = list(users.merge(transactions,how='inner',on='UserID').sort_values(by='TransactionDate'))
data = pd.merge(users,transactions.groupby('UserID').first(),how='left',on = 'UserID')

# %%
my_columns = list(data.columns)
my_columns
# Out:
# ['UserID',
#  'User',
#  'Gender',
#  'Registered',
#  'Cancelled',
#  'TransactionID',
#  'TransactionDate',
#  'ProductID',
#  'Quantity']

# %%
my_col = list(data.dropna(thresh=int(data.shape[0]*.9),axis=1).columns)

# %%
my_col
# Out:
# ['UserID', 'User', 'Gender', 'Registered']

# %%
missing_info = list(data.columns[data.isnull().any()])
missing_info
# Out:
# ['Cancelled', 'TransactionID', 'TransactionDate', 'ProductID', 'Quantity']
